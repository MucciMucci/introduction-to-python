# %%
Mylist = ('alpha', 'beta', 'gamma', 'delta', 'epsilon','zeta')
a='alpha'
b='beta'
c='gamma'
d='delta'
e='epsilon'
f='zeta'
print (Mylist)
len(Mylist)
type(Mylist)
# Out:
# ('alpha', 'beta', 'gamma', 'delta', 'epsilon', 'zeta')
# tuple

# %%
print (a)
# Out:
# alpha

# %%
print (a,b,c,d,e,f)
# Out:
# alpha beta gamma delta epsilon zeta

# %%
a,b,c,d,e,f = f,e,d,c,b,a
print (a,b,c,d,e,f)
# Out:
# zeta epsilon delta gamma beta alpha

# %%
num = int(input("Enter a number: "))  
if (num % 2) == 0:  
   print("{0} is Even number".format(num))  
else:  
   print("{0} is Odd number".format(num))
